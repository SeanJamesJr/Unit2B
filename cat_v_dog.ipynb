# %%
import os
traning_data = os.listdir('train')

# %%
labels =[]

for x in traning_data:
    if 'cat' in x:
        labels.append(0)
    else:
        labels.append(1)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

cat_image = img.imread("train/cat.10300.jpg")
plt.imshow(cat_image)
